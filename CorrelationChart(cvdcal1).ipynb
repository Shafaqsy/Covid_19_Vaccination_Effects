# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Add Matplotlib inline magic command
# %matplotlib inline
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
#CHANGE THE FILE NAME
data_file = "cvdcal1.csv"

# %%
# Use Pandas to read data
data_file = pd.read_csv(data_file)
data_file.head()
# Out:
#        date        area area_type  cases  cumulative_cases  deaths  \
# 0  2/1/2020  California     State     24                24       0
# 1  2/2/2020  California     State      9                33       0
# 2  2/3/2020  California     State      7                40       0
# 3  2/4/2020  California     State      1                41       0
# 4  2/5/2020  California     State      3                44       0
#
#    cumulative_deaths  total_tests  cumulative_total_tests  positive_tests  \
# 0                  0        304.0                     304             9.0
# 1                  0         36.0                     340             2.0
# 2                  0         29.0                     369             1.0
# 3                  0         32.0                     401             1.0
# 4                  0         45.0                     446             1.0
#
#    cumulative_positive_tests  reported_cases  cumulative_reported_cases  \
# 0                          9               3                          3
# 1                         11               3                          6
# 2                         12               0                          6
# 3                         13               0                          6
# 4                         14               0                          6
#
#    reported_deaths  cumulative_reported_deaths  reported_tests
# 0                0                           0             NaN
# 1                0                           0             NaN
# 2                0                           0             NaN
# 3                0                           0             NaN
# 4                0                           0             NaN

# %%
data_file.corr()
# Out:
#                                cases  cumulative_cases    deaths  \
# cases                       1.000000          0.153090  0.406086
# cumulative_cases            0.153090          1.000000 -0.150673
# deaths                      0.406086         -0.150673  1.000000
# cumulative_deaths           0.150654          0.941344 -0.129021
# total_tests                 0.654536          0.254580  0.334353
# cumulative_total_tests      0.160604          0.990687 -0.201469
# positive_tests              0.995455          0.168814  0.409025
# cumulative_positive_tests   0.146055          0.999844 -0.160278
# reported_cases              0.568018          0.137447  0.337606
# cumulative_reported_cases   0.128606          0.999608 -0.164758
# reported_deaths             0.147587         -0.076264  0.642169
# cumulative_reported_deaths  0.135949          0.945876 -0.189032
# reported_tests              0.236891          0.552314  0.073092
#
#                             cumulative_deaths  total_tests  \
# cases                                0.150654     0.654536
# cumulative_cases                     0.941344     0.254580
# deaths                              -0.129021     0.334353
# cumulative_deaths                    1.000000     0.375210
# total_tests                          0.375210     1.000000
# cumulative_total_tests               0.946634     0.276274
# positive_tests                       0.166493     0.679019
# cumulative_positive_tests            0.936949     0.246536
# reported_cases                       0.124963     0.354992
# cumulative_reported_cases            0.940612     0.239821
# reported_deaths                     -0.023208     0.233529
# cumulative_reported_deaths           0.997200     0.351990
# reported_tests                       0.504514     0.182975
#
#                             cumulative_total_tests  positive_tests  \
# cases                                     0.160604        0.995455
# cumulative_cases                          0.990687        0.168814
# deaths                                   -0.201469        0.409025
# cumulative_deaths                         0.946634        0.166493
# total_tests                               0.276274        0.679019
# cumulative_total_tests                    1.000000        0.172628
# positive_tests                            0.172628        1.000000
# cumulative_positive_tests                 0.990843        0.161820
# reported_cases                            0.130149        0.564719
# cumulative_reported_cases                 0.990387        0.144293
# reported_deaths                          -0.130434        0.164085
# cumulative_reported_deaths                0.956211        0.150500
# reported_tests                            0.568352        0.235749
#
#                             cumulative_positive_tests  reported_cases  \
# cases                                        0.146055        0.568018
# cumulative_cases                             0.999844        0.137447
# deaths                                      -0.160278        0.337606
# cumulative_deaths                            0.936949        0.124963
# total_tests                                  0.246536        0.354992
# cumulative_total_tests                       0.990843        0.130149
# positive_tests                               0.161820        0.564719
# cumulative_positive_tests                    1.000000        0.132529
# reported_cases                               0.132529        1.000000
# cumulative_reported_cases                    0.999666        0.122335
# reported_deaths                             -0.083480        0.322883
# cumulative_reported_deaths                   0.942236        0.111034
# reported_tests                               0.551274        0.654052
#
#                             cumulative_reported_cases  reported_deaths  \
# cases                                        0.128606         0.147587
# cumulative_cases                             0.999608        -0.076264
# deaths                                      -0.164758         0.642169
# cumulative_deaths                            0.940612        -0.023208
# total_tests                                  0.239821         0.233529
# cumulative_total_tests                       0.990387        -0.130434
# positive_tests                               0.144293         0.164085
# cumulative_positive_tests                    0.999666        -0.083480
# reported_cases                               0.122335         0.322883
# cumulative_reported_cases                    1.000000        -0.082037
# reported_deaths                             -0.082037         1.000000
# cumulative_reported_deaths                   0.945795        -0.078220
# reported_tests                               0.544511         0.262952
#
#                             cumulative_reported_deaths  reported_tests
# cases                                         0.135949        0.236891
# cumulative_cases                              0.945876        0.552314
# deaths                                       -0.189032        0.073092
# cumulative_deaths                             0.997200        0.504514
# total_tests                                   0.351990        0.182975
# cumulative_total_tests                        0.956211        0.568352
# positive_tests                                0.150500        0.235749
# cumulative_positive_tests                     0.942236        0.551274
# reported_cases                                0.111034        0.654052
# cumulative_reported_cases                     0.945795        0.544511
# reported_deaths                              -0.078220        0.262952
# cumulative_reported_deaths                    1.000000        0.500582
# reported_tests                                0.500582        1.000000

# %%
sns.heatmap(data_file.corr());
